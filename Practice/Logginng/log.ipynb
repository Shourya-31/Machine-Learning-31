# %%
import logging

## Configure the basic logging settings
logging.basicConfig(level=logging.DEBUG)

## log messeges
logging.debug("This is a debug messege")
logging.info("This is a info messege")
logging.warning("This is a warning messege")
logging.error("This is a error messege")
logging.critical("This is a critical messege")
# Out:
# DEBUG:root:This is a debug messege
# INFO:root:This is a info messege
# WARNING:root:This is a warning messege
# ERROR:root:This is a error messege
# CRITICAL:root:This is a critical messege

# %%
## Configuring logging
import logging # Have to restart the kernal

logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

## log messeges
logging.debug("This is a debug messege")
logging.info("This is a info messege")
logging.warning("This is a warning messege")
logging.error("This is a error messege")
logging.critical("This is a critical messege")
