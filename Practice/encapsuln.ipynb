# %%
### Encapsulation  with Getter and Setter MEthods
### Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name,age):
        self.name=name    ## public variables
        self.age=age      ## public variables

def get_name(person):
    return person.name

person=Person("Krish",34)
get_name(person)
# Out:
# 'Krish'

# %%
### Encapsulation  with Getter and Setter MEthods
### Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name,age,gender):
        self.__name=name    ## private variables
        self.__age=age      ## private variables
        self.gender=gender

def get_name(person):
    return person.name

person=Person("Krish",34)
get_name(person)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10 def get_name(person):
#      11     return person.name
# ---> 13 person=Person("Krish",34)
#      14 get_name(person)
#
# TypeError: Person.__init__() missing 1 required positional argument: 'gender'

# %%
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
### Encapsulation  with Getter and Setter MEthods
### Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name,age,gender):
        self._name=name    ## protected variables
        self._age=age      ## protected variables
        self.gender=gender

def get_name(person):
    return person.name

person=Person("Krish",34,"Male")
print(person._name)
# Out:
# Krish

# %%
class Person:
    def __init__(self,name,age):
        self.__name=name
        self.__age=age
    
    ## Getter method
    def get_name(self):
        return self.__name

    ## Setter method
    def set_name(self,name):
        self.__name=name

    ## Getter method
    def get_age(self):
        return self.__age

    ## Setter method
    def set_age(self,age):
        if age>0:
            self.__age=age
        else:
            print("Age cannot be negative")

person=Person("Sho",23)

## Accessing and modifying private vars using getter and setter

print(person.get_name())
print(person.get_age())

person.set_age(24)
print(person.get_age())

person.set_age(-1)

person.set_name("Shourya")
print(person.get_name())
# Out:
# Sho
# 23
# 24
# Age cannot be negative
# Shourya
