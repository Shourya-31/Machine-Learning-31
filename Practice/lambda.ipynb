# %%
#Syntax of Lambda 
lambda arguments: expressiom
# Out:
# Hii

# %%
addn=lambda a,b: a+b

type(addn)

print(addn(5,6))
# Out:
# 11

# %%
even = lambda num:num%2==0
even(12)
# Out:
# True

# %%
addn1 = lambda x,y,z: (x+y)/z

print(addn1(1,2,3))
# Out:
# 1.0

# %%
## map()- Apllies a function to all items in the list

nums = [1,2,3,4,5,6,7,8,9]

def sqaure(nums):
    return nums**2

sqaure(4)
# Out:
# 16

# %%
list(map(lambda x:x**2,nums))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]
