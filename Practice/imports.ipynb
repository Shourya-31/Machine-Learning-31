# %%
import math
import numpy

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi

print(sqrt(64)*pi)
# Out:
# 25.132741228718345

# %%
from math import *

# %%
from package1.mathz import addn

addn(2,3)
# Out:
# 5

# %%
from package1.subpackagess.multing import multiply

multiply(5,5)
# Out:
# 25
