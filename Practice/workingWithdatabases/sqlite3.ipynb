# %%
import sqlite3

# %%
## Connect to a SQLite database
connection=sqlite3.connect('examplez.db')
connection

# %%
cursor=connection.cursor()

# %%
## Create a Table
cursor.execute('''
 Create Table If Not Exists employee(
    id Integer Primary Key,
    name Text Not Null,
    age Integer,
    department Text)          
''')

## Commit the changes
connection.commit()

# %%
cursor.execute('''
Select * from employee
''')

# %%
## INsert the data in sqlite table
cursor.execute('''
Insert into employee(name,age,department)
               values('SHo',23,'Gen AI Engineer')
''')

cursor.execute('''
Insert into employee(name,age,department)
               values('SHou',24,'Gen AI Engineer1')
''')

cursor.execute('''
Insert into employee(name,age,department)
               values('SHour',25,'Gen AI Engineer3')
''')

## Commit changes
connection.commit()

# %%
## Query the data from the table
cursor.execute('Select * from employee')
rows=cursor.fetchall() # Use to get all records from select * cmd

# Print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'SHo', 23, 'Gen AI Engineer')
# (2, 'SHou', 24, 'Gen AI Engineer1')
# (3, 'SHour', 25, 'Gen AI Engineer3')
# (4, 'SHo', 23, 'Gen AI Engineer')
# (5, 'SHou', 24, 'Gen AI Engineer1')
# (6, 'SHour', 25, 'Gen AI Engineer3')
# (7, 'SHo', 23, 'Gen AI Engineer')
# (8, 'SHou', 24, 'Gen AI Engineer1')
# (9, 'SHour', 25, 'Gen AI Engineer3')

# %%
## Update the data in the table
cursor.execute('''
UPDATE employee
Set age = 31
where name="SHo"
''')

connection.commit()

# %%
## Query the data from the table
cursor.execute('Select * from employee')
rows=cursor.fetchall() # Use to get all records from select * cmd

# Print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'SHo', 31, 'Gen AI Engineer')
# (2, 'SHou', 24, 'Gen AI Engineer1')
# (3, 'SHour', 25, 'Gen AI Engineer3')
# (4, 'SHo', 31, 'Gen AI Engineer')
# (5, 'SHou', 24, 'Gen AI Engineer1')
# (6, 'SHour', 25, 'Gen AI Engineer3')
# (7, 'SHo', 31, 'Gen AI Engineer')
# (8, 'SHou', 24, 'Gen AI Engineer1')
# (9, 'SHour', 25, 'Gen AI Engineer3')

# %%
## Delete the data from the table

cursor.execute('''
Delete from employee
               where name='SHou'
''')

connection.commit()

# %%
## Query the data from the table
cursor.execute('Select * from employee')
rows=cursor.fetchall() # Use to get all records from select * cmd

# Print the queried data
for row in rows:
    print(row)
# Out:
# (1, 'SHo', 31, 'Gen AI Engineer')
# (3, 'SHour', 25, 'Gen AI Engineer3')
# (4, 'SHo', 31, 'Gen AI Engineer')
# (6, 'SHour', 25, 'Gen AI Engineer3')
# (7, 'SHo', 31, 'Gen AI Engineer')
# (9, 'SHour', 25, 'Gen AI Engineer3')

# %%
## WOrking with Sales Data

# Connect to an SQLite database
connection=sqlite3.connect('Salez_data.db')
cursor=connection.cursor()

# Create a table for sales data
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    date TEXT NOT NULL,
    product TEXT NOT NULL,
    sales INTEGER,
    region TEXT
    )
''')


# Insert data into the sales table
sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 200, 'South'),
    ('2023-01-03', 'Product1', 150, 'East'),
    ('2023-01-04', 'Product3', 250, 'West'),
    ('2023-01-05', 'Product2', 300, 'North')
]

cursor.executemany('''
Insert into sales(date,product,sales,region)
                   values(?,?,?,?)
''',sales_data)

connection.commit()

# %%
cursor.execute('SELECT * FROM sales')
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 200, 'South')
# (3, '2023-01-03', 'Product1', 150, 'East')
# (4, '2023-01-04', 'Product3', 250, 'West')
# (5, '2023-01-05', 'Product2', 300, 'North')

# %%
# Permanently close the connection
connection.close()

# %%
cursor.execute('SELECT * FROM sales')
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 cursor.execute('SELECT * FROM sales')
#       2 rows=cursor.fetchall()
#       4 for row in rows:
#
# ProgrammingError: Cannot operate on a closed database.
