# %%
import numpy as np

# %%
lst_marks=[40,41,42,65,57,48,99,88,69,79,33,23,31]
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(23.0),
#  np.float64(40.0),
#  np.float64(48.0),
#  np.float64(69.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
# Out:
# np.float64(-3.5)

# %%
higher_fence
# Out:
# np.float64(112.5)

# %%
import seaborn as sns

# %%
sns.boxenplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[40,41,42,65,57,48,99,88,69,79,33,23,31,120,-10]

# %%
sns.boxenplot(lst_marks)
# Out:
# <Axes: >
