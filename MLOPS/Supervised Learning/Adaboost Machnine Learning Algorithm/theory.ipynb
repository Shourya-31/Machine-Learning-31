# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### If we are trying to create a DT to its complete depth, it usually leads to overfitting. Since in RF we have multiple DT, and we are using multiple base-learners.
#
# ### Now in Boosting we create weak learners from the DS. We will connect multiple weak learners in sequential manner.

# %% [markdown]
# ### Now on combining each of them gives us strong learner
# ### Weak Learner implies it has not learnt much from DS while strong learner is opposite of weak learner

# %% [markdown]
# ### In Adaboost we assign weights to weak learner

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Mi is weak learner and alpha i is weight. With help this sequential learning we solve regression and clasification problems

# %% [markdown]
# ### Tree Stump- Depth is just 1 level

# %% [markdown]
# ### These are called weak learners, lead to under-fitting. This means that training acc is less but test can be more or less.

# %% [markdown]
# ### Now on combining them all together along with their respective weights we will get low bias and high variance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step-1
# ### We will make a DT Stump first
# ### Let us make salary less than 50k, o/p are 2, Yes or No

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Now let us select one of them for the first DT Stump

# %% [markdown]
# ### Now if we calculate Entropy and Gini Impurity for both the DT, the 2nd one will get much better one.

# %% [markdown]
# ### Step-2

# %% [markdown]
# ### We will assign sample weights:- 1/7

# %% [markdown]
# ### Now when we took this particular stump, when my credit score was good, I got three yes and zero nos.
#
# ### In the case of no I got one yes and zero nos. Right.
#
# ### But over here, with respect to our data set, I don't have any scenario where my credit score was good and I was getting no as an answer.
#
# ### So this one yes is basically my error, right?
#
# ### This is my error.

# %% [markdown]
# ### If we train with this particular DS, we will get error as Yes in this particular record

# %% [markdown]
# ### Now computing total error. We will use total nu,ber of wrong records.

# %% [markdown]
# ### We are gonna calc performance of stump

# %% [markdown]
# ### Formula:-
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Now 1/7 = TE
# ### Therefore 0.896 is the performance.
# ### It specifies:- Performance of model/Adaboost

# %% [markdown]
# ### Function of Adaboost:-
# ![image.png](attachment:image.png)
#
# ### alpha 1 is weight

# %% [markdown]
# ### Formula for weight updation:-
# ### We basically have 2 formulas, one for incorrect classified points and one for correctly classified points

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Therefore, (1/7)*e^(-0.896)

# %% [markdown]
# ### After updating weights weights via this formula
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Normilasing Weights and Assigning Bins

# %% [markdown]
# ### What we will do is, we will divide the weights with 0.697 which is total of updated weights.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Now we want that the records which are incorrectly classified should be sent to next stump.
# ### For that we will make bins with certain ranges.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### The range is quiet high for wrong record

# %% [markdown]
# ### Now in the next step, we are going to find out a way that what are the records that are going to get captured to go to the next decision tree stump one okay.

# %% [markdown]
# ### Lets continue an iterative process in which we will select random values between 0s and 1s.

# %% [markdown]
# ###

# %% [markdown]
# ### Let us assign random values between 0 and 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### These records will be sent to the next DT Stump.
#  ### Again the steps will be repeated, like sample weights

# %% [markdown]
# ### Then a2(M2) will be selected.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Now we will combine these values and see the prediction

# %% [markdown]
# ## Final Prediction

# %% [markdown]
# ![image.png](attachment:image.png)
