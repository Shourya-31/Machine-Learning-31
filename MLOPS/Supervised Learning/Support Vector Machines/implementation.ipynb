# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# Lets consider we have 2 axis. ![image.png](attachment:image.png)
#
#
# This image implies Logistic Regresssion

# %% [markdown]
# With Support Vector Classifier-
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Along with this Best-Fit line we create 2 marginal plane

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this, we make sure that these 2 marginal planes has maximum distance. The marginal planes passes through nearest points from best fit lines. Those 2 points are called Support Vectors.

# %% [markdown]
# ## Soft Margin & Hard Margin

# %% [markdown]
# ### Soft Margin:-

# %% [markdown]
# Here will be an overlapping and so some amount of errors. Therefore we cant have a clear best fit line and marginal planes.

# %% [markdown]
# ### Hard Margin:-
#
# Here we dont get any errors as there is no overlapping and errors.

# %% [markdown]
# ### In depth Math Intuition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# => Here w is a vector parpendicular to the best fit line

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now we will get the equations of 2 marginal planes and then we will substract their values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now we will get the unit vecrtor by dividing wT with ||w||
#
# The cost functions comes as 2/||w||

# %% [markdown]
# Constraints:-
#
#
# yi = {+1 | wTx+b >= 1}
#
# yi = {-1 | wTx+b <= -1}

# %% [markdown]
# For all correct points. If we multiply yi*(wTx+b) >= 1
