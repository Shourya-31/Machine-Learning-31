# %% [markdown]
# ## ALgorithms we will learn in Bagging:- Random Forest

# %% [markdown]
# ### Idea behind Bagging

# %% [markdown]
# ### We have some specific base learners, we pass some amount of data to these base learners. Then we bag what the results of maximum base learners is and finalize it

# %% [markdown]
# ### Base Learners run parallely

# %% [markdown]
# ## Boosting:- Adaboost, XGboost, Gradient boost

# %% [markdown]
# ### Idea behind Boosting

# %% [markdown]
# ### Here we have weak learners

# %% [markdown]
# ### The models are conncected sequencially

# %% [markdown]
# ### We combine them sequencially and gert one single strong learner
