# %% [markdown]
# ### Step-1:- Create a Base Model

# %% [markdown]
# #### Calculate the average sum of all truth y that will be output of our base model

# %% [markdown]
# ### Step-2:- Compare Residual Error
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step-3:- Construct DT consider i/p xi and o/p Ri

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### We multiply DT with alpha, learning rate

# %% [markdown]
# ### Like this we will compute o/p for all the records
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### We will repeat all these steps, that we will compute residual and make DT and then get y hats. While working with base model as 75

# %% [markdown]
# ![image.png](attachment:image.png)
