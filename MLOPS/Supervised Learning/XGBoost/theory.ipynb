# %% [markdown]
# ## XGboost Math Intuition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Dataset and base model

# %% [markdown]
# #### Since it is a binary dataset therefore it will have a probability of 0.5

# %% [markdown]
# #### Therefire y hat  = 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Now is the time to calculate similarity weight

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This has similarity weight of Left Child, Right Child and Root Node

# %% [markdown]
# #### Now we will take another feature and make a split

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### For these categories too we will calculate the similarity weights.

# %% [markdown]
# #### The data must pass through the log of odds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### After passing it to base model we pass it to log of odds and then sigmoid activation function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This was for the first record

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Like this there will be many values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This is our Extreme Gradient Boost Classifier

# %% [markdown]
# ## XGBoost Regressor Algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ####  To select the feature and probably construct the decision tree, we use something called as similarity weight

# %% [markdown]
# #### Now for the first step we will create a base model

# %% [markdown]
# #### Second step, calculate the residual
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### After this we have to calculate Gains

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Like this we will calculate o/p for all other records

# %% [markdown]
# #### After calculating that we will calculate R2 (Residual) in another coloumn
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
