# %% [markdown]
# # Decision Tree Classifier
#
# A **Decision Tree Classifier** is a supervised machine learning algorithm used for **classification problems**.
# It works like a flowchart where:
#
# * Each **internal node** represents a condition/test on a feature.
# * Each **branch** represents the outcome of the test.
# * Each **leaf node** represents the final class prediction.
#
# ## Working
#
# The algorithm repeatedly splits the dataset into smaller subsets based on the feature that gives the **best separation** between classes.
#
# Common splitting criteria:
#
# * **Gini Impurity**
# * **Entropy / Information Gain**
#
# ## Steps
#
# 1. Select the best feature for splitting.
# 2. Divide the dataset into branches.
# 3. Repeat splitting recursively.
# 4. Stop when data is pure or stopping condition is reached.
#
# ## Advantages
#
# * Easy to understand and visualize.
# * Works with numerical and categorical data.
# * Requires little data preprocessing.
# * Handles non-linear relationships well.
#
# ## Disadvantages
#
# * Can overfit on training data.
# * Sensitive to small changes in data.
# * Large trees become complex.
#
# ## Applications
#
# * Spam detection
# * Medical diagnosis
# * Customer segmentation
# * Fraud detection
#
# ## Example
#
# If predicting whether a person buys a laptop:
#
# * Age < 30?
#
#   * Yes → Student?
#
#     * Yes → Buy
#     * No → Not Buy
#   * No → Income High?
#
#     * Yes → Buy
#     * No → Not Buy
#
# ## Important Terms
#
# * **Root Node**: Starting node of the tree.
# * **Leaf Node**: Final prediction/output node.
# * **Depth**: Maximum level of the tree.
# * **Pruning**: Removing unnecessary branches to reduce overfitting.

# %% [markdown]
# ## Entropy & Gini Impurity

# %% [markdown]
# ### Entropy:- H(s) = -p + log2(p+) - (p-) - log2(p-)

# %% [markdown]
# ### p+ => Being one category
#
# ### p- => Being other category

# %% [markdown]
# ### Gini Impurity:- G.I. = 1 - sum from i to n (p)^2

# %% [markdown]
# ### If we have 6Y/3N

# %% [markdown]
# #### Then we divide it into 2 parts:-
#
# #### 3Y/3N (Impure Seperation)
# #### And 3Y/0N (Pure Seperation)

# %% [markdown]
# #### Now if we check H(c1) = -p+log2(p+)-(p-)log2(p-)

# %% [markdown]
# #### With p = 3/6 and p- = 3/6
# #### Then H(c1) = 1 => Impure Split

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This is the curve we get w.r.t. Entropy

# %% [markdown]
# #### And Gini Impurity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### This is the max value we get for impure split w.r.t. Gini Impurity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### When we checked for 3Y/0N

# %% [markdown]
# ### To know which feature we should select for spliting we need information gain

# %% [markdown]
# Formula:-
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Sv is how many number of category remains after the split

# %% [markdown]
# Therefore Sv = 8/14 in first split

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### With categories both formulas expands ![image.png](attachment:image.png)

# %% [markdown]
# ### If DS is small use Entropy, if DS is large then Gini Impurity

# %% [markdown]
# ## Decision Tree Split for Numerical Feature

# %% [markdown]
# ###  Sort the feature value and pick up a threshold

# %% [markdown]
# ### Once a decision tree is made with comparision based nodes
# ### Jump to next threshold

# %% [markdown]
# ## Post & Pre Prunning

# %% [markdown]
# #### To avoid Overfitting scenerio (train acc high and test acc low) we do prunning

# %% [markdown]
# ### We cut the branch to avoid going into unnecessary depths

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Post Prunning:- Smaller DS

# %% [markdown]
# ### In Pre Prunning we dont construct entire decision tree

# %% [markdown]
# ### Hyperparameter tuning while constructing DT

# %% [markdown]
# ## Decision Tree Regression

# %% [markdown]
# #### To choose which split we should select we will use variance reduction (regression problem)

# %% [markdown]
# #### Instead of using Entropy or Gini Impurity we use Mean Squared Error

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# #### We compute variance of root then the children

# %% [markdown]
# #### Once we have computed variance of all of them, we will apply variance reduction formula

# %% [markdown]
#  ![image.png](attachment:image.png)
#
# wi => weight => How many o/p are there in left/right node

# %% [markdown]
# #### In above example we computed for leftm similarly we can compute for right

# %% [markdown]
# #### After computing variance reduction for each desicion split individually we will compare which one is better. And thus we will select the better split
